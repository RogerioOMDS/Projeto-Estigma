# %%
import pandas as pd
import pdfplumber
import requests

# %%
url = 'pdf1.pdf'

# %%
with pdfplumber.open(url) as pdf:
    text = pdf.pages[0].extract_text()

# %%
len(pdf.pages)
# Out:
# 34

# %%
texto = []

# %%
with pdfplumber.open(url) as pdf:
    for i in range(0,len(pdf.pages)):
        text = pdf.pages[i].extract_text()
        texto.append(text)

# %%
texto
# Out:
# ['35\nPORTOALEGRE,QUINTA-FEIRA,26/1/2012\nO tempo hoje\n“Preﬁro os malvados aos\nimbecis, porque os malvados, às Osantododia\nvezes, descansam.”\nTimóteoeTito\nAlexandreDumasﬁlho,escritorfrancês\n(1824-1895)\nArte do Leitor A Social\nJorgeDutraenviaacaricaturadeMichelTeló, “AfotoédaminhaﬁlhaThaila,\nosucessonacionaleinternacionalcoma quecompletoudoisaninhosem\nmúsicaAi,SeEutePego. dezembro.Oregistrofoiemumdia\nmuitoquente.”\nMicheleCosta,PortoAlegre\n“Querohomenagearmeu\nmaridoEderson,quefez\naniversárionestemês.Euamo-o\nmuito.Todaafamíliaenviavotos\ndefelicidade.”\nPâmeladaSilva,Guaíba\n“Tenho\nmuita\nadmiração\npelosmeus\navós\nmaternos,\nMariaCelenie\nOscarTadeu\nSantarém.”\nBeatriz\nBarbosa,\nPortoAlegre\nMeu sonho é Comunitárias\nPrecisoderoupinhasdebebê, “Desejorealizarosonhode\numcarrinhoeberço.Podesertudo minhairmã.Elaquermuitouma ●CURSINHO–AongXama\nusado.Estoudesempregada.Meu máquinadecostura.Podeser deDuasFaces,quemantémo\nmaridovendebalasemsinaleiras, usada.Elaquertrabalh
# ...

# %%
with pdfplumber.open(url) as pdf:
    for i in range(0,len(pdf.pages)):
        text = pdf.pages[i].extract_text()
        if 'esquizofrenico' in text: print('pagina ${i}.')

# %%
for i in range(len(pdf.pages)):
    if 'esquizofrenia' in texto[i]: print(f'pagina {i}')
# Out:
# pagina 0
# pagina 1
# pagina 2
# pagina 3
# pagina 4
# pagina 5
# pagina 6
# pagina 7
# pagina 8
# pagina 9
# pagina 10
# pagina 11
# pagina 12
# pagina 13
# pagina 14
# pagina 16
# pagina 17
# pagina 18
# pagina 19
# pagina 20
# pagina 21
# pagina 22
# pagina 23
# pagina 24
# pagina 25
# pagina 26
# pagina 27
# pagina 28
# pagina 29
# pagina 30
# pagina 32
# pagina 33

# %%
if 'esquizofrenia' in texto[6]: print('show')
# Out:
# show

# %%
with pdfplumber.open(url) as pdf:
    text = pdf.pages[0].extract_text()
text
# Out:
# '35\nPORTOALEGRE,QUINTA-FEIRA,26/1/2012\nO tempo hoje\n“Preﬁro os malvados aos\nimbecis, porque os malvados, às Osantododia\nvezes, descansam.”\nTimóteoeTito\nAlexandreDumasﬁlho,escritorfrancês\n(1824-1895)\nArte do Leitor A Social\nJorgeDutraenviaacaricaturadeMichelTeló, “AfotoédaminhaﬁlhaThaila,\nosucessonacionaleinternacionalcoma quecompletoudoisaninhosem\nmúsicaAi,SeEutePego. dezembro.Oregistrofoiemumdia\nmuitoquente.”\nMicheleCosta,PortoAlegre\n“Querohomenagearmeu\nmaridoEderson,quefez\naniversárionestemês.Euamo-o\nmuito.Todaafamíliaenviavotos\ndefelicidade.”\nPâmeladaSilva,Guaíba\n“Tenho\nmuita\nadmiração\npelosmeus\navós\nmaternos,\nMariaCelenie\nOscarTadeu\nSantarém.”\nBeatriz\nBarbosa,\nPortoAlegre\nMeu sonho é Comunitárias\nPrecisoderoupinhasdebebê, “Desejorealizarosonhode\numcarrinhoeberço.Podesertudo minhairmã.Elaquermuitouma ●CURSINHO–AongXama\nusado.Estoudesempregada.Meu máquinadecostura.Podeser deDuasFaces,quemantémo\nmaridovendebalasemsinaleiras, usada.Elaquertrabalha
# ...

# %%
if 'esquizofrenia' in text: print('show')
# Out:
# show
